# %% [markdown]
# # AnimeGM - Autoencoder with batch normalization - Keras
# GOAL: Generate new anime-style images
#
# View model: `$ tensorboard --logdir=autoencoder`
#
# Methodology:
# 1. Build a dataset of images suitable for out needs
# 2. Build a generative model.
# 3. Train the model
# 4. Transfer style to a photo

# %% [markdown]
# ### Imports

# %%
import keras
from keras.callbacks import ModelCheckpoint, TensorBoard
from keras.layers import Activation, Conv2D, Dense, Flatten, Input, MaxPooling2D, Reshape, UpSampling2D
from keras.layers.normalization import BatchNormalization
from keras.models import Model
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
import os
from os import listdir, path
import pandas as pd
import seaborn as sns; sns.set()
from skimage import color, data, transform
import tensorflow as tf
# %matplotlib inline
# Out:
# /home/peter/.local/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %% [markdown]
# ### Functions

# %%
# tf image preprocessing
# load, decoded and resize
def parse_image(flatten, n_channels, path, resize_dim):
    """parses an image and converts it to the type we want.
    flatten: to flatten the image into a vector or not.
    n_channels: number of color channels to set (color / grayscale) - 1 or 3.
    path: path to the image.
    resize_dim: the number of pixels the image should be per size.
    
    return: the image as a vector or matrix
    """
    
    image_string = tf.read_file(path)
    
    # decode
    image = tf.image.decode_jpeg(image_string, channels=3)
    
    # check for 1 channel
    # if so, grayscale
    if (n_channels == 1):
        image = tf.image.rgb_to_grayscale(image)
        
    # resize the image
    image = tf.image.resize_images(image, [resize_dim, resize_dim])
    
#     # feature normalize the image
#     image = tf.divide(image, 255)
    
    # standardize the image
    image = tf.image.per_image_standardization(image)
    
    # check if we want the image flattened
    # if so, flatten the image
    if flatten == True:
        image = tf.reshape(image, [-1])
    
    return image

# %%
def data_generator(paths, iter, mode, sess):   
    """Creates a data generator.
    paths: image paths to feed the generator with.
    iter: TF dataset iterator.
    mode: the mode we want (train or test).
    sess: instance of a TF session.
    
    return: an image batch
    """
    
    next_batch = iter.get_next()
    
    # Initialize an iterator over a dataset.
    sess.run(iter.initializer, feed_dict={image_paths: paths})

    # yield the next batch
    while 1:
        batch = sess.run(next_batch)
        
        # check for mode
        if mode == 'train':
            result = batch, batch
        elif mode == 'test':
            result = batch
            
        yield result

# %%
def show_image(image, n_channels, resize_dim):
    """Shows an image.
    image: image data to show.
    n_channels: number of color channels to set (color / grayscale) - 1 or 3.
    resize_dim: the number of pixels the image should be per size.
    """
    
    # check for 1 channel
    # if so, grayscale
    if (n_channels == 1):
        image = image.reshape((resize_dim, resize_dim))
    else:
        image = image.reshape((resize_dim, resize_dim, n_channels))

    plt.imshow(image, cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
def show_images(images, n_channels, resize_dim):
    """Shows a set of images.
    images: a set of image data to show.
    n_channels: number of color channels to set (color / grayscale) - 1 or 3.
    resize_dim: the number of pixels the image should be per size.
    """
    
   # get the number of images
    n_images = images.shape[0]
    
    if n_images == 1:
        show_image(images[0], n_channels, resize_dim)
        return
    
    # get the square root of the number of images
    squareroot = int(np.ceil(np.sqrt(n_images)))
    
    # size of the figure
    figsize = (10, 10)
    
    # configure subplots
    fig, ax = plt.subplots(squareroot, squareroot, figsize=figsize,
                           subplot_kw=dict(xticks=[], yticks=[]))
    fig.subplots_adjust(hspace=0.05, wspace=0.05)

    for i, axi in enumerate(ax.flat):
        # exit if the index of subplots is greater than amount of images
        if i > n_images - 1:
            return
        
        image = images[i]
        
        # check for 1 channel
        # if so, grayscale
        if (n_channels == 1):
            image = image.reshape((resize_dim, resize_dim))
        else:
            image = image.reshape((resize_dim, resize_dim, n_channels))

        im = axi.imshow(image, cmap='gray')

# %%
def transform_image(image, n_channels, resize_dim):
    """Gray scales an image (if enough channels) and resizes it aswell.
    image: image data.
    resize_dim: new image dimension.
    
    return grayscaled, resized image
    """
    
    # check for 1 channel
    # if so, grayscale
    if (n_channels == 1):
        image = color.rgb2gray(image)
    
    # Resize the image
    image = transform.resize(image, (resize_dim, resize_dim))
    
    return image

# %% [markdown]
# ### Variables

# %%
# data dir
dir_name = 'danbooru-small'

# log dir
log_dir = 'log'

# checkpoint path
checkpoint_path = 'checkpoints/weights.best.hdf5'

# model dir
model_path = 'models/model.hdf5'

cores = 4

# %%
# data manipulation
resize_dim = 128
n_channels = 3
n_features = resize_dim * resize_dim * n_channels

# model type: flatten false for cnn
flatten = False

# %%
# number of examples
n_test = 10 # for reconstruction - subset of validation
n_train = 5000 # for training
n_validation = int(n_train * 0.2) # for training validation

# %%
# hyper parameters~~~~
batch_size = 30
n_batches = int(n_train / batch_size)
n_validation_batches = int(n_validation / batch_size)

n_epochs = 200

# for a cnn layer between encoder / decoder
# cnn_dim = int(resize_dim / 2 / 2 / 2)

# %% [markdown]
# # Configure GPUs

# %%
os.environ["CUDA_VISIBLE_DEVICES"]="0"

# %% [markdown]
# ## 1. Build a dataset
# Pull in an existing dataset and modify it for my needs.
#
# Lets start with the danbooru 2017 anime image dataset. Now this dataset is huge. So we are only going to use 1 torrent of the SFW subset.

# %% [markdown]
# ### Prepare data

# %%
# get filenames and join paths as np array
base_filenames = listdir(dir_name)
filename_paths = [path.join(dir_name, base_filename) for base_filename in base_filenames]
filename_paths = np.array(filename_paths)

# %%
# create paths for train and test
test_paths = filename_paths[:n_test]
train_paths = filename_paths[:-n_validation][:n_train]
validation_paths = filename_paths[:n_validation]

# %% [markdown]
# ### Create dataset

# %%
with tf.device('/cpu:0'):
    # create a placeholder for image_paths
    image_paths = tf.placeholder(tf.string, shape=[None])

    # create a dataset from the paths
    dataset = tf.data.Dataset.from_tensor_slices(image_paths)
    dataset = dataset.apply(tf.contrib.data.map_and_batch(
                            map_func=lambda image_paths: parse_image(flatten, n_channels, image_paths, resize_dim),
                            num_parallel_batches=1,
                            batch_size=batch_size))
    dataset = dataset.cache()
    dataset = dataset.prefetch(buffer_size=batch_size)
    dataset = dataset.shuffle(buffer_size=n_train)
    dataset = dataset.repeat()

    # iterators
    iter = dataset.make_initializable_iterator()

# %% [markdown]
# ## 2. Build a generative model
# Lets build an autoencoder

# %%
# input placeholder
inputs = Input(shape=(resize_dim, resize_dim, n_channels))

# encoded the input with convolutions and pooling
x = Conv2D(64, (3, 3), name='encoder_0', padding='same')(inputs)
x = BatchNormalization(name='batch_normlization_0')(x)
x = Activation('relu', name='activation_0')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool_0')(x)

x = Conv2D(128, (3, 3), name='encoder_1', padding='same')(x)
x = BatchNormalization(name='batch_normlization_1')(x)
x = Activation('relu', name='activation_1')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool_1')(x)

x = Conv2D(512, (3, 3), name='encoder_2', padding='same')(x)
x = BatchNormalization(name='batch_normlization_2')(x)
x = Activation('relu', name='activation_2')(x)
x = MaxPooling2D((2, 2), padding='same', name='pool_2')(x)

x = Conv2D(512, (3, 3), name='encoder_3', padding='same')(x)
x = BatchNormalization(name='batch_normlization_3')(x)
x = Activation('relu', name='activation_3')(x)
encoded = MaxPooling2D((2, 2), padding='same', name='pool_3')(x)

# decoded the compression and upsampling
x = Conv2D(512, (3, 3), name='decoder_0', padding='same')(encoded)
x = BatchNormalization(name='batch_normlization_4')(x)
x = Activation('relu', name='activation_4')(x)
x = UpSampling2D((2, 2), name='upsample_0')(x)

x = Conv2D(512, (3, 3), name='decoder_1', padding='same')(x)
x = BatchNormalization(name='batch_normlization_5')(x)
x = Activation('relu', name='activation_5')(x)
x = UpSampling2D((2, 2), name='upsample_1')(x)

x = Conv2D(128, (3, 3), name='decoder_2', padding='same')(x)
x = BatchNormalization(name='batch_normlization_6')(x)
x = Activation('relu', name='activation_6')(x)
x = UpSampling2D((2, 2), name='upsample_2')(x)

x = Conv2D(n_channels, (3, 3), name='decoder_3', padding='same')(x)
x = BatchNormalization(name='batch_normlization_7')(x)
x = UpSampling2D((2, 2), name='upsample_3')(x)
decoded = Activation('relu', name='activation_7')(x)

# %% [markdown]
# ### Compile the model with cost and optimizer

# %%
# this model maps inputs to its reconstructions
autoencoder = Model(inputs, decoded)

# %%
# load model weights if they exist
if path.isfile(checkpoint_path):
    autoencoder.load_weights(checkpoint_path)

# %%
autoencoder.compile(loss='mean_squared_error', 
                    optimizer='adadelta')

# %% [markdown]
# ## 3. Train the model

# %%
# create a session to use the graph
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True))

# create instances of the generator
training_batch_generator = data_generator(train_paths, iter, 'train', sess)
validation_batch_generator = data_generator(validation_paths, iter, 'train', sess)
test_batch_generator = data_generator(test_paths, iter, 'test', sess)
 
# create checkpoint for weights
checkpoint = ModelCheckpoint(checkpoint_path, verbose=1, 
                             save_best_only=True, save_weights_only=True,
                             monitor='val_loss', mode='min')

# %%
# train
autoencoder.fit_generator(training_batch_generator, 
                          steps_per_epoch=n_batches,
                          epochs=n_epochs,
                          validation_data=validation_batch_generator,
                          validation_steps=n_validation_batches,
                          callbacks=[checkpoint, TensorBoard(log_dir=log_dir)])
# Out:
# Epoch 1/200
# 166/166 [==============================] - 62s 376ms/step - loss: 0.6935 - val_loss: 0.6634
#
# Epoch 00001: val_loss improved from inf to 0.66344, saving model to checkpoints/weights.best.hdf5
# Epoch 2/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6489 - val_loss: 0.6602
#
# Epoch 00002: val_loss improved from 0.66344 to 0.66019, saving model to checkpoints/weights.best.hdf5
# Epoch 3/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6420 - val_loss: 0.6417
#
# Epoch 00003: val_loss improved from 0.66019 to 0.64170, saving model to checkpoints/weights.best.hdf5
# Epoch 4/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6376 - val_loss: 0.6381
#
# Epoch 00004: val_loss improved from 0.64170 to 0.63814, saving model to checkpoints/weights.best.hdf5
# Epoch 5/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6356 - val_loss: 0.6366
#
# Epoch 00005: val_loss improved from 0.63814 to 0.63657, saving model to checkpoints/weights.best.hdf5
# Epoch 6/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6308 - val_loss: 0.6380
#
# Epoch 00006: val_loss did not improve
# Epoch 7/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6311 - val_loss: 0.6394
#
# Epoch 00007: val_loss did not improve
# Epoch 8/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6277 - val_loss: 0.6322
#
# Epoch 00008: val_loss improved from 0.63657 to 0.63217, saving model to checkpoints/weights.best.hdf5
# Epoch 9/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6275 - val_loss: 0.6298
#
# Epoch 00009: val_loss improved from 0.63217 to 0.62977, saving model to checkpoints/weights.best.hdf5
# Epoch 10/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6273 - val_loss: 0.6340
#
# Epoch 00010: val_loss did not improve
# Epoch 11/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6267 - val_loss: 0.6245
#
# Epoch 00011: val_loss improved from 0.62977 to 0.62449, saving model to checkpoints/weights.best.hdf5
# Epoch 12/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6255 - val_loss: 0.6239
#
# Epoch 00012: val_loss improved from 0.62449 to 0.62386, saving model to checkpoints/weights.best.hdf5
# Epoch 13/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6268 - val_loss: 0.6231
#
# Epoch 00013: val_loss improved from 0.62386 to 0.62308, saving model to checkpoints/weights.best.hdf5
# Epoch 14/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6223 - val_loss: 0.6308
#
# Epoch 00014: val_loss did not improve
# Epoch 15/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6241 - val_loss: 0.6265
#
# Epoch 00015: val_loss did not improve
# Epoch 16/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6241 - val_loss: 0.6200
#
# Epoch 00016: val_loss improved from 0.62308 to 0.61996, saving model to checkpoints/weights.best.hdf5
# Epoch 17/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6236 - val_loss: 0.6257
#
# Epoch 00017: val_loss did not improve
# Epoch 18/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6224 - val_loss: 0.6194
#
# Epoch 00018: val_loss improved from 0.61996 to 0.61938, saving model to checkpoints/weights.best.hdf5
# Epoch 19/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6218 - val_loss: 0.6190
#
# Epoch 00019: val_loss improved from 0.61938 to 0.61900, saving model to checkpoints/weights.best.hdf5
# Epoch 20/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6228 - val_loss: 0.6247
#
# Epoch 00020: val_loss did not improve
# Epoch 21/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6210 - val_loss: 0.6257
#
# Epoch 00021: val_loss did not improve
# Epoch 22/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6207 - val_loss: 0.6199
#
# Epoch 00022: val_loss did not improve
# Epoch 23/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6209 - val_loss: 0.6186
#
# Epoch 00023: val_loss improved from 0.61900 to 0.61857, saving model to checkpoints/weights.best.hdf5
# Epoch 24/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6197 - val_loss: 0.6225
#
# Epoch 00024: val_loss did not improve
# Epoch 25/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6215 - val_loss: 0.6205
#
# Epoch 00025: val_loss did not improve
# Epoch 26/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6194 - val_loss: 0.6212
#
# Epoch 00026: val_loss did not improve
# Epoch 27/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6192 - val_loss: 0.6198
#
# Epoch 00027: val_loss did not improve
# Epoch 28/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6195 - val_loss: 0.6254
#
# Epoch 00028: val_loss did not improve
# Epoch 29/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6178 - val_loss: 0.6228
#
# Epoch 00029: val_loss did not improve
# Epoch 30/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6191 - val_loss: 0.6183
#
# Epoch 00030: val_loss improved from 0.61857 to 0.61833, saving model to checkpoints/weights.best.hdf5
# Epoch 31/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6188 - val_loss: 0.6177
#
# Epoch 00031: val_loss improved from 0.61833 to 0.61766, saving model to checkpoints/weights.best.hdf5
# Epoch 32/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6171 - val_loss: 0.6233
#
# Epoch 00032: val_loss did not improve
# Epoch 33/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6177 - val_loss: 0.6232
#
# Epoch 00033: val_loss did not improve
# Epoch 34/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6180 - val_loss: 0.6202
#
# Epoch 00034: val_loss did not improve
# Epoch 35/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6180 - val_loss: 0.6131
#
# Epoch 00035: val_loss improved from 0.61766 to 0.61308, saving model to checkpoints/weights.best.hdf5
# Epoch 36/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6179 - val_loss: 0.6161
#
# Epoch 00036: val_loss did not improve
# Epoch 37/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6163 - val_loss: 0.6195
#
# Epoch 00037: val_loss did not improve
# Epoch 38/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6193 - val_loss: 0.6109
#
# Epoch 00038: val_loss improved from 0.61308 to 0.61089, saving model to checkpoints/weights.best.hdf5
# Epoch 39/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6170 - val_loss: 0.6171
#
# Epoch 00039: val_loss did not improve
# Epoch 40/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6177 - val_loss: 0.6172
#
# Epoch 00040: val_loss did not improve
# Epoch 41/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6177 - val_loss: 0.6132
#
# Epoch 00041: val_loss did not improve
# Epoch 42/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6154 - val_loss: 0.6228
#
# Epoch 00042: val_loss did not improve
# Epoch 43/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6149 - val_loss: 0.6209
#
# Epoch 00043: val_loss did not improve
# Epoch 44/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6161 - val_loss: 0.6146
#
# Epoch 00044: val_loss did not improve
# Epoch 45/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6173 - val_loss: 0.6177
#
# Epoch 00045: val_loss did not improve
# Epoch 46/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6160 - val_loss: 0.6155
#
# Epoch 00046: val_loss did not improve
# Epoch 47/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6149 - val_loss: 0.6157
#
# Epoch 00047: val_loss did not improve
# Epoch 48/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6157 - val_loss: 0.6205
#
# Epoch 00048: val_loss did not improve
# Epoch 49/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6163 - val_loss: 0.6170
#
# Epoch 00049: val_loss did not improve
# Epoch 50/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6151 - val_loss: 0.6124
#
# Epoch 00050: val_loss did not improve
# Epoch 51/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6154 - val_loss: 0.6152
#
# Epoch 00051: val_loss did not improve
# Epoch 52/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6146 - val_loss: 0.6130
#
# Epoch 00052: val_loss did not improve
# Epoch 53/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6165 - val_loss: 0.6163
#
# Epoch 00053: val_loss did not improve
# Epoch 54/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6149 - val_loss: 0.6083
#
# Epoch 00054: val_loss improved from 0.61089 to 0.60829, saving model to checkpoints/weights.best.hdf5
# Epoch 55/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6172 - val_loss: 0.6105
#
# Epoch 00055: val_loss did not improve
# Epoch 56/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6139 - val_loss: 0.6197
#
# Epoch 00056: val_loss did not improve
# Epoch 57/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6135 - val_loss: 0.6142
#
# Epoch 00057: val_loss did not improve
# Epoch 58/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6152 - val_loss: 0.6156
#
# Epoch 00058: val_loss did not improve
# Epoch 59/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6142 - val_loss: 0.6117
#
# Epoch 00059: val_loss did not improve
# Epoch 60/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6141 - val_loss: 0.6138
#
# Epoch 00060: val_loss did not improve
# Epoch 61/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6162 - val_loss: 0.6124
#
# Epoch 00061: val_loss did not improve
# Epoch 62/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6127 - val_loss: 0.6164
#
# Epoch 00062: val_loss did not improve
# Epoch 63/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6145 - val_loss: 0.6121
#
# Epoch 00063: val_loss did not improve
# Epoch 64/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6141 - val_loss: 0.6129
#
# Epoch 00064: val_loss did not improve
# Epoch 65/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6145 - val_loss: 0.6118
#
# Epoch 00065: val_loss did not improve
# Epoch 66/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6127 - val_loss: 0.6134
#
# Epoch 00066: val_loss did not improve
# Epoch 67/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6137 - val_loss: 0.6123
#
# Epoch 00067: val_loss did not improve
# Epoch 68/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6135 - val_loss: 0.6180
#
# Epoch 00068: val_loss did not improve
# Epoch 69/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6122 - val_loss: 0.6190
#
# Epoch 00069: val_loss did not improve
# Epoch 70/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6133 - val_loss: 0.6199
#
# Epoch 00070: val_loss did not improve
# Epoch 71/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6131 - val_loss: 0.6100
#
# Epoch 00071: val_loss did not improve
# Epoch 72/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6137 - val_loss: 0.6170
#
# Epoch 00072: val_loss did not improve
# Epoch 73/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6115 - val_loss: 0.6154
#
# Epoch 00073: val_loss did not improve
# Epoch 74/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6137 - val_loss: 0.6103
#
# Epoch 00074: val_loss did not improve
# Epoch 75/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6133 - val_loss: 0.6164
#
# Epoch 00075: val_loss did not improve
# Epoch 76/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6118 - val_loss: 0.6130
#
# Epoch 00076: val_loss did not improve
# Epoch 77/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6128 - val_loss: 0.6110
#
# Epoch 00077: val_loss did not improve
# Epoch 78/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6108 - val_loss: 0.6178
#
# Epoch 00078: val_loss did not improve
# Epoch 79/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6113 - val_loss: 0.6190
#
# Epoch 00079: val_loss did not improve
# Epoch 80/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6140 - val_loss: 0.6075
#
# Epoch 00080: val_loss improved from 0.60829 to 0.60747, saving model to checkpoints/weights.best.hdf5
# Epoch 81/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6126 - val_loss: 0.6115
#
# Epoch 00081: val_loss did not improve
# Epoch 82/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6105 - val_loss: 0.6193
#
# Epoch 00082: val_loss did not improve
# Epoch 83/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6130 - val_loss: 0.6128
#
# Epoch 00083: val_loss did not improve
# Epoch 84/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6136 - val_loss: 0.6079
#
# Epoch 00084: val_loss did not improve
# Epoch 85/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6122 - val_loss: 0.6108
#
# Epoch 00085: val_loss did not improve
# Epoch 86/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6113 - val_loss: 0.6105
#
# Epoch 00086: val_loss did not improve
# Epoch 87/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6125 - val_loss: 0.6135
#
# Epoch 00087: val_loss did not improve
# Epoch 88/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6109 - val_loss: 0.6115
#
# Epoch 00088: val_loss did not improve
# Epoch 89/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6126 - val_loss: 0.6064
#
# Epoch 00089: val_loss improved from 0.60747 to 0.60636, saving model to checkpoints/weights.best.hdf5
# Epoch 90/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6114 - val_loss: 0.6096
#
# Epoch 00090: val_loss did not improve
# Epoch 91/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6128 - val_loss: 0.6134
#
# Epoch 00091: val_loss did not improve
# Epoch 92/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6115 - val_loss: 0.6091
#
# Epoch 00092: val_loss did not improve
# Epoch 93/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6112 - val_loss: 0.6112
#
# Epoch 00093: val_loss did not improve
# Epoch 94/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6120 - val_loss: 0.6153
#
# Epoch 00094: val_loss did not improve
# Epoch 95/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6106 - val_loss: 0.6146
#
# Epoch 00095: val_loss did not improve
# Epoch 96/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6129 - val_loss: 0.6026
#
# Epoch 00096: val_loss improved from 0.60636 to 0.60264, saving model to checkpoints/weights.best.hdf5
# Epoch 97/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6110 - val_loss: 0.6137
#
# Epoch 00097: val_loss did not improve
# Epoch 98/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6103 - val_loss: 0.6099
#
# Epoch 00098: val_loss did not improve
# Epoch 99/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6115 - val_loss: 0.6102
#
# Epoch 00099: val_loss did not improve
# Epoch 100/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6114 - val_loss: 0.6143
#
# Epoch 00100: val_loss did not improve
# Epoch 101/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6107 - val_loss: 0.6130
#
# Epoch 00101: val_loss did not improve
# Epoch 102/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6096 - val_loss: 0.6085
#
# Epoch 00102: val_loss did not improve
# Epoch 103/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6120 - val_loss: 0.6127
#
# Epoch 00103: val_loss did not improve
# Epoch 104/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6099 - val_loss: 0.6106
#
# Epoch 00104: val_loss did not improve
# Epoch 105/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6102 - val_loss: 0.6119
#
# Epoch 00105: val_loss did not improve
# Epoch 106/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6103 - val_loss: 0.6144
#
# Epoch 00106: val_loss did not improve
# Epoch 107/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6107 - val_loss: 0.6074
#
# Epoch 00107: val_loss did not improve
# Epoch 108/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6102 - val_loss: 0.6133
#
# Epoch 00108: val_loss did not improve
# Epoch 109/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6101 - val_loss: 0.6121
#
# Epoch 00109: val_loss did not improve
# Epoch 110/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6092 - val_loss: 0.6085
#
# Epoch 00110: val_loss did not improve
# Epoch 111/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6122 - val_loss: 0.6138
#
# Epoch 00111: val_loss did not improve
# Epoch 112/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6099 - val_loss: 0.6065
#
# Epoch 00112: val_loss did not improve
# Epoch 113/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6094 - val_loss: 0.6091
#
# Epoch 00113: val_loss did not improve
# Epoch 114/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6111 - val_loss: 0.6168
#
# Epoch 00114: val_loss did not improve
# Epoch 115/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6094 - val_loss: 0.6084
#
# Epoch 00115: val_loss did not improve
# Epoch 116/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6095 - val_loss: 0.6103
#
# Epoch 00116: val_loss did not improve
# Epoch 117/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6109 - val_loss: 0.6102
#
# Epoch 00117: val_loss did not improve
# Epoch 118/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6100 - val_loss: 0.6146
#
# Epoch 00118: val_loss did not improve
# Epoch 119/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6090 - val_loss: 0.6076
#
# Epoch 00119: val_loss did not improve
# Epoch 120/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6093 - val_loss: 0.6215
#
# Epoch 00120: val_loss did not improve
# Epoch 121/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6100 - val_loss: 0.6098
#
# Epoch 00121: val_loss did not improve
# Epoch 122/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6098 - val_loss: 0.6180
#
# Epoch 00122: val_loss did not improve
# Epoch 123/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6090 - val_loss: 0.6054
#
# Epoch 00123: val_loss did not improve
# Epoch 124/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6099 - val_loss: 0.6039
#
# Epoch 00124: val_loss did not improve
# Epoch 125/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6116 - val_loss: 0.6070
#
# Epoch 00125: val_loss did not improve
# Epoch 126/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6115 - val_loss: 0.6116
#
# Epoch 00126: val_loss did not improve
# Epoch 127/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6095 - val_loss: 0.6070
#
# Epoch 00127: val_loss did not improve
# Epoch 128/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6091 - val_loss: 0.6125
#
# Epoch 00128: val_loss did not improve
# Epoch 129/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6082 - val_loss: 0.6069
#
# Epoch 00129: val_loss did not improve
# Epoch 130/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6110 - val_loss: 0.6093
#
# Epoch 00130: val_loss did not improve
# Epoch 131/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6083 - val_loss: 0.6124
#
# Epoch 00131: val_loss did not improve
# Epoch 132/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6105 - val_loss: 0.6052
#
# Epoch 00132: val_loss did not improve
# Epoch 133/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6065 - val_loss: 0.6153
#
# Epoch 00133: val_loss did not improve
# Epoch 134/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6107 - val_loss: 0.6101
#
# Epoch 00134: val_loss did not improve
# Epoch 135/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6091 - val_loss: 0.6092
#
# Epoch 00135: val_loss did not improve
# Epoch 136/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6090 - val_loss: 0.6052
#
# Epoch 00136: val_loss did not improve
# Epoch 137/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6094 - val_loss: 0.6139
#
# Epoch 00137: val_loss did not improve
# Epoch 138/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6085 - val_loss: 0.6087
#
# Epoch 00138: val_loss did not improve
# Epoch 139/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6084 - val_loss: 0.6078
#
# Epoch 00139: val_loss did not improve
# Epoch 140/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6081 - val_loss: 0.6122
#
# Epoch 00140: val_loss did not improve
# Epoch 141/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6085 - val_loss: 0.6089
#
# Epoch 00141: val_loss did not improve
# Epoch 142/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6104 - val_loss: 0.6017
#
# Epoch 00142: val_loss improved from 0.60264 to 0.60173, saving model to checkpoints/weights.best.hdf5
# Epoch 143/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6094 - val_loss: 0.6068
#
# Epoch 00143: val_loss did not improve
# Epoch 144/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6091 - val_loss: 0.6083
#
# Epoch 00144: val_loss did not improve
# Epoch 145/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6083 - val_loss: 0.6123
#
# Epoch 00145: val_loss did not improve
# Epoch 146/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6081 - val_loss: 0.6071
#
# Epoch 00146: val_loss did not improve
# Epoch 147/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6090 - val_loss: 0.6156
#
# Epoch 00147: val_loss did not improve
# Epoch 148/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6067 - val_loss: 0.6084
#
# Epoch 00148: val_loss did not improve
# Epoch 149/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6088 - val_loss: 0.6093
#
# Epoch 00149: val_loss did not improve
# Epoch 150/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6079 - val_loss: 0.6136
#
# Epoch 00150: val_loss did not improve
# Epoch 151/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6087 - val_loss: 0.6060
#
# Epoch 00151: val_loss did not improve
# Epoch 152/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6085 - val_loss: 0.6078
#
# Epoch 00152: val_loss did not improve
# Epoch 153/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6090 - val_loss: 0.6061
#
# Epoch 00153: val_loss did not improve
# Epoch 154/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6088 - val_loss: 0.6060
#
# Epoch 00154: val_loss did not improve
# Epoch 155/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6073 - val_loss: 0.6107
#
# Epoch 00155: val_loss did not improve
# Epoch 156/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6080 - val_loss: 0.6088
#
# Epoch 00156: val_loss did not improve
# Epoch 157/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6084 - val_loss: 0.6047
#
# Epoch 00157: val_loss did not improve
# Epoch 158/200
# 166/166 [==============================] - 53s 322ms/step - loss: 0.6072 - val_loss: 0.6154
#
# Epoch 00158: val_loss did not improve
# Epoch 159/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6085 - val_loss: 0.6115
#
# Epoch 00159: val_loss did not improve
# Epoch 160/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6070 - val_loss: 0.6156
#
# Epoch 00160: val_loss did not improve
# Epoch 161/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6074 - val_loss: 0.6059
#
# Epoch 00161: val_loss did not improve
# Epoch 162/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6086 - val_loss: 0.6026
#
# Epoch 00162: val_loss did not improve
# Epoch 163/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6077 - val_loss: 0.6121
#
# Epoch 00163: val_loss did not improve
# Epoch 164/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6083 - val_loss: 0.6116
#
# Epoch 00164: val_loss did not improve
# Epoch 165/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6058 - val_loss: 0.6160
#
# Epoch 00165: val_loss did not improve
# Epoch 166/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6069 - val_loss: 0.6088
#
# Epoch 00166: val_loss did not improve
# Epoch 167/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6070 - val_loss: 0.6159
#
# Epoch 00167: val_loss did not improve
# Epoch 168/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6075 - val_loss: 0.6111
#
# Epoch 00168: val_loss did not improve
# Epoch 169/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6071 - val_loss: 0.6048
#
# Epoch 00169: val_loss did not improve
# Epoch 170/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6081 - val_loss: 0.6119
#
# Epoch 00170: val_loss did not improve
# Epoch 171/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6069 - val_loss: 0.6118
#
# Epoch 00171: val_loss did not improve
# Epoch 172/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6081 - val_loss: 0.6095
#
# Epoch 00172: val_loss did not improve
# Epoch 173/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6043 - val_loss: 0.6152
#
# Epoch 00173: val_loss did not improve
# Epoch 174/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6084 - val_loss: 0.6100
#
# Epoch 00174: val_loss did not improve
# Epoch 175/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6071 - val_loss: 0.6075
#
# Epoch 00175: val_loss did not improve
# Epoch 176/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6082 - val_loss: 0.6081
#
# Epoch 00176: val_loss did not improve
# Epoch 177/200
# 166/166 [==============================] - 53s 322ms/step - loss: 0.6073 - val_loss: 0.6071
#
# Epoch 00177: val_loss did not improve
# Epoch 178/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6063 - val_loss: 0.6150
#
# Epoch 00178: val_loss did not improve
# Epoch 179/200
# 166/166 [==============================] - 53s 322ms/step - loss: 0.6069 - val_loss: 0.6110
#
# Epoch 00179: val_loss did not improve
# Epoch 180/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6064 - val_loss: 0.6117
#
# Epoch 00180: val_loss did not improve
# Epoch 181/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6060 - val_loss: 0.6091
#
# Epoch 00181: val_loss did not improve
# Epoch 182/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6074 - val_loss: 0.6084
#
# Epoch 00182: val_loss did not improve
# Epoch 183/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6073 - val_loss: 0.6079
#
# Epoch 00183: val_loss did not improve
# Epoch 184/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6072 - val_loss: 0.6129
#
# Epoch 00184: val_loss did not improve
# Epoch 185/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6061 - val_loss: 0.6098
#
# Epoch 00185: val_loss did not improve
# Epoch 186/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6067 - val_loss: 0.6071
#
# Epoch 00186: val_loss did not improve
# Epoch 187/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6073 - val_loss: 0.6065
#
# Epoch 00187: val_loss did not improve
# Epoch 188/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6072 - val_loss: 0.6082
#
# Epoch 00188: val_loss did not improve
# Epoch 189/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6072 - val_loss: 0.6075
#
# Epoch 00189: val_loss did not improve
# Epoch 190/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6067 - val_loss: 0.6115
#
# Epoch 00190: val_loss did not improve
# Epoch 191/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6064 - val_loss: 0.6083
#
# Epoch 00191: val_loss did not improve
# Epoch 192/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6072 - val_loss: 0.6100
#
# Epoch 00192: val_loss did not improve
# Epoch 193/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6060 - val_loss: 0.6066
#
# Epoch 00193: val_loss did not improve
# Epoch 194/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6075 - val_loss: 0.6048
#
# Epoch 00194: val_loss did not improve
# Epoch 195/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6060 - val_loss: 0.6034
#
# Epoch 00195: val_loss did not improve
# Epoch 196/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6077 - val_loss: 0.6056
#
# Epoch 00196: val_loss did not improve
# Epoch 197/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6075 - val_loss: 0.6027
#
# Epoch 00197: val_loss did not improve
# Epoch 198/200
# 166/166 [==============================] - 53s 320ms/step - loss: 0.6080 - val_loss: 0.6092
#
# Epoch 00198: val_loss did not improve
# Epoch 199/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6047 - val_loss: 0.6115
#
# Epoch 00199: val_loss did not improve
# Epoch 200/200
# 166/166 [==============================] - 53s 321ms/step - loss: 0.6085 - val_loss: 0.6077
#
# Epoch 00200: val_loss did not improve

# %%
# Create reconstructions  
# get batch
test_batch = next(test_batch_generator)

# show the test images
show_images(test_batch, n_channels, resize_dim)

# create reconstructions
reconstructions = autoencoder.predict(test_batch)

# show the reconstructioned test images
show_images(reconstructions, n_channels, resize_dim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## 4. Apply model to a real image

# %%
# grab an image
transfer_image = data.astronaut()

# resize the image and put it into gray scale
resized_transfer_image = transform_image(transfer_image, n_channels, resize_dim)

# batch it
reshaped_transfer_image = resized_transfer_image.reshape(-1, resize_dim, resize_dim, n_channels)

# display an image
show_image(resized_transfer_image, n_channels, resize_dim)
# Out:
# /home/peter/anaconda3/lib/python3.6/site-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
# run the image through the model
test_y = autoencoder.predict(reshaped_transfer_image)

# view the resulting image
show_image(test_y, n_channels, resize_dim)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # 5. Export model for production use

# %%
# export the trained model in TF.js Layers format
autoencoder.save(model_path)
