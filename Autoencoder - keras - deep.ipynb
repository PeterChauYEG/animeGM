# %% [markdown]
# # AnimeGM - Autoencoder - Keras
# GOAL: Generate new anime-style images
#
# Methodology:
# 1. Build a dataset of images suitable for out needs
# 2. Build a generative model.
# 3. Train the model
# 4. Generate a new image with random numbers
# 5. Transfer style to a photo
# 6. Examine results

# %% [markdown]
# ## 1. Build a dataset
# Pull in an existing dataset and modify it for my needs.
#
# Lets start with the danbooru 2017 anime image dataset. Now this dataset is huge. So we are only going to use 1 torrent of the SFW subset.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
import seaborn as sns; sns.set()
from skimage.transform import resize
from os import listdir
from os.path import join
from skimage import data
import tensorflow as tf
from tensorflow.python.framework.ops import reset_default_graph
# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
# tf image preprocessing
# load, decoded and resize
def parse_image(image_path):
    image_string = tf.read_file(image_path)
    image_decoded = tf.image.decode_jpeg(image_string, channels=3)
    image_grayscaled = tf.image.rgb_to_grayscale(image_decoded)
    image_resized = tf.image.resize_images(image_grayscaled, [resize_dim, resize_dim])
    image_normalized = tf.divide(image_resized, 255)
    image_reshaped = tf.reshape(image_normalized, [-1])
    return image_reshaped

# %%
def show_image(image):
    image_reshape = image.reshape((resize_dim, resize_dim))
    plt.imshow(image_reshape, cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
def show_images(images, figsize=(10, 10)):
   # get the number of images
    n_images = images.shape[0]
    
    if n_images == 1:
        show_image(images[0])
        return
    
    # get the square root of the number of images
    squareroot = int(np.ceil(np.sqrt(n_images)))
    
    fig, ax = plt.subplots(squareroot, squareroot, figsize=figsize,
                           subplot_kw=dict(xticks=[], yticks=[]))
    fig.subplots_adjust(hspace=0.05, wspace=0.05)

    for i, axi in enumerate(ax.flat):
        # exit if the index of subplots is greater than amount of images
        if i > n_images - 1:
            return
        image_reshape = images[i].reshape((resize_dim, resize_dim))
        im = axi.imshow(image_reshape, cmap='gray')

# %% [markdown]
# ### Variables

# %%
dir_name = 'danbooru-small'

# %%
n_train = 2200
n_test = 10

resize_dim = 28
n_features = resize_dim * resize_dim

# %%
# hyper parameters~~~~
batch_size = 50
n_batches = int(n_train / batch_size)
n_epochs = 10

# %% [markdown]
# ### Prepare data

# %%
# get filenames and join paths as np array
base_filenames = listdir(dir_name)
filename_paths = [join(dir_name, base_filename) for base_filename in base_filenames]
filename_paths = np.array(filename_paths)

# %%
# create paths for train and test
train_paths = filename_paths[:-n_test][:n_train]
test_paths = filename_paths[:n_test]

# %%
# reset the current graph and start over
reset_default_graph()

# %%
# create a dataset from the paths
image_paths = tf.placeholder(tf.string, shape=[None])
dataset = tf.data.Dataset.from_tensor_slices(image_paths)
dataset = dataset.map(parse_image)
dataset = dataset.shuffle(buffer_size=n_train)
dataset = dataset.batch(batch_size)
dataset = dataset.repeat()

# iterators
iter = dataset.make_initializable_iterator()
next_ele = iter.get_next()

# %% [markdown]
# ## 2. Build a generative model
# Lets build an autoencoder

# %%
import keras
from keras.layers import Dense, Input, Reshape
from keras.models import Model
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
# size of encoded representations
encoding_dims = 32

# %%
# input placeholder
inputs = Input(shape=(n_features,))

# encoded represation of the input
encoded = Dense(256, activation='relu', name='encoder_0')(inputs)
encoded = Dense(128, activation='relu', name='encoder_1')(encoded)
encoded = Dense(64, activation='relu', name='encoder_2')(encoded)
encoded = Dense(encoding_dims, activation='relu', name='encoder_3')(encoded)

# decoded lossy reconstruction of the input
decoded = Dense(64, activation='relu', name='decoder_0')(encoded)
decoded = Dense(128, activation='relu', name='decoder_1')(decoded)
decoded = Dense(256, activation='relu', name='decoder_2')(decoded)
decoded = Dense(n_features, activation='sigmoid', name='decoder_3')(decoded)

# %%
# this model maps inputs to its reconstructions
autoencoder = Model(inputs, decoded)

# %%
# this model maps inputs to encoded represations
encoder = Model(inputs, encoded)

# %%
# create a placeholder for an ancoded input
encoded_input = Input(shape=(encoding_dims,))

# get the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-4]

# create decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# ### Compile the model with cost and optimizer

# %%
autoencoder.compile(loss='binary_crossentropy', 
              optimizer='adadelta')

# %% [markdown]
# ## 3. Train the model

# %%
# create a session to use the graph
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
# Initialize an iterator over a training dataset.
sess.run(iter.initializer, feed_dict={image_paths: train_paths})
    
for epoch_i in range(n_epochs):
    for batch_i in range(n_batches):
        # get batch
        batch_X = sess.run(next_ele)

        # train
        autoencoder.fit(batch_X, batch_X, epochs=1, batch_size=batch_size)
# Out:
# Epoch 1/1
# 50/50 [==============================] - 1s 12ms/step - loss: 0.6935
# Epoch 1/1
# 50/50 [==============================] - 0s 559us/step - loss: 0.6934
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.6932
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.6929
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6925
# Epoch 1/1
# 50/50 [==============================] - 0s 561us/step - loss: 0.6926
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.6924
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.6920
# Epoch 1/1
# 50/50 [==============================] - 0s 659us/step - loss: 0.6917
# Epoch 1/1
# 50/50 [==============================] - 0s 661us/step - loss: 0.6916
# Epoch 1/1
# 50/50 [==============================] - 0s 539us/step - loss: 0.6913
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.6909
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.6913
# Epoch 1/1
# 50/50 [==============================] - 0s 701us/step - loss: 0.6912
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6909
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.6901
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.6887
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.6891
# Epoch 1/1
# 50/50 [==============================] - 0s 599us/step - loss: 0.6880
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6874
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.6865
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.6854
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.6860
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6826
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6820
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.6791
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.6752
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.6716
# Epoch 1/1
# 50/50 [==============================] - 0s 601us/step - loss: 0.6757
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.6672
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.6680
# Epoch 1/1
# 50/50 [==============================] - 0s 601us/step - loss: 0.6610
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6527
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.6572
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.6309
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.6219
# Epoch 1/1
# 50/50 [==============================] - 0s 799us/step - loss: 0.5983
# Epoch 1/1
# 50/50 [==============================] - 0s 661us/step - loss: 0.6074
# Epoch 1/1
# 50/50 [==============================] - 0s 561us/step - loss: 0.6083
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.5907
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5869
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.5843
# Epoch 1/1
# 50/50 [==============================] - 0s 621us/step - loss: 0.5959
# Epoch 1/1
# 44/44 [==============================] - 0s 727us/step - loss: 0.5574
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.5400
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5434
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5491
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5361
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5428
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5571
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5509
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5450
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5280
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5289
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5197
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5347
# Epoch 1/1
# 50/50 [==============================] - 0s 521us/step - loss: 0.5531
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5506
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5178
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5350
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5055
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5137
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5038
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.4958
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5461
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5200
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5334
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5246
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5460
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5550
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5075
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4980
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5433
# Epoch 1/1
# 50/50 [==============================] - 0s 820us/step - loss: 0.5470
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5351
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5286
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5442
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4860
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5447
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5517
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5228
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5416
# Epoch 1/1
# 50/50 [==============================] - 0s 620us/step - loss: 0.5596
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5177
# Epoch 1/1
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5047
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5481
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5213
# Epoch 1/1
# 44/44 [==============================] - 0s 614us/step - loss: 0.5009
# Epoch 1/1
# 50/50 [==============================] - 0s 601us/step - loss: 0.5227
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.4944
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5543
# Epoch 1/1
# 50/50 [==============================] - 0s 820us/step - loss: 0.4972
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5661
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5133
# Epoch 1/1
# 50/50 [==============================] - 0s 820us/step - loss: 0.5188
# Epoch 1/1
# 50/50 [==============================] - 0s 743us/step - loss: 0.5530
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5338
# Epoch 1/1
# 50/50 [==============================] - 0s 537us/step - loss: 0.5110
# Epoch 1/1
# 50/50 [==============================] - 0s 974us/step - loss: 0.5227
# Epoch 1/1
# 50/50 [==============================] - 0s 740us/step - loss: 0.5017
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.4982
# Epoch 1/1
# 50/50 [==============================] - 0s 701us/step - loss: 0.4828
# Epoch 1/1
# 50/50 [==============================] - 0s 800us/step - loss: 0.5205
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.5228
# Epoch 1/1
# 50/50 [==============================] - 0s 621us/step - loss: 0.5177
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5130
# Epoch 1/1
# 50/50 [==============================] - 0s 720us/step - loss: 0.5037
# Epoch 1/1
# 50/50 [==============================] - 0s 708us/step - loss: 0.5017
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.5260
# Epoch 1/1
# 50/50 [==============================] - 0s 646us/step - loss: 0.4833
# Epoch 1/1
# 50/50 [==============================] - 0s 836us/step - loss: 0.5386
# Epoch 1/1
# 50/50 [==============================] - 0s 720us/step - loss: 0.5350
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.5163
# Epoch 1/1
# 50/50 [==============================] - 0s 601us/step - loss: 0.5338
# Epoch 1/1
# 50/50 [==============================] - 0s 753us/step - loss: 0.5579
# Epoch 1/1
# 50/50 [==============================] - 0s 923us/step - loss: 0.5411
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.5018
# Epoch 1/1
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5204
# Epoch 1/1
# 50/50 [==============================] - 0s 679us/step - loss: 0.5210
# Epoch 1/1
# 50/50 [==============================] - 0s 803us/step - loss: 0.5128
# Epoch 1/1
# 50/50 [==============================] - 0s 840us/step - loss: 0.5063
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.5507
# Epoch 1/1
# 50/50 [==============================] - 0s 660us/step - loss: 0.5250
# Epoch 1/1
# 50/50 [==============================] - 0s 720us/step - loss: 0.4934
# Epoch 1/1
# 50/50 [==============================] - 0s 801us/step - loss: 0.5456
# Epoch 1/1
# 50/50 [==============================] - 0s 760us/step - loss: 0.5289
# Epoch 1/1
# 50/50 [==============================] - 0s 820us/step - loss: 0.4926
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.4964
# Epoch 1/1
# 50/50 [==============================] - 0s 740us/step - loss: 0.5203
# Epoch 1/1
# 50/50 [==============================] - 0s 779us/step - loss: 0.5444
# Epoch 1/1
# 50/50 [==============================] - 0s 819us/step - loss: 0.5183
# Epoch 1/1
# 44/44 [==============================] - 0s 864us/step - loss: 0.5186
# Epoch 1/1
# 50/50 [==============================] - 0s 624us/step - loss: 0.5014
# Epoch 1/1
# 50/50 [==============================] - 0s 515us/step - loss: 0.5059
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5246
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5417
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5058
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5491
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5381
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4814
# Epoch 1/1
# 50/50 [==============================] - 0s 501us/step - loss: 0.5060
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4967
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5411
# Epoch 1/1
# 50/50 [==============================] - 0s 521us/step - loss: 0.5430
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5083
# Epoch 1/1
# 50/50 [==============================] - 0s 461us/step - loss: 0.5256
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5151
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5211
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5153
# Epoch 1/1
# 50/50 [==============================] - 0s 516us/step - loss: 0.5219
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4999
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4878
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5098
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4677
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5137
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5059
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.5257
# Epoch 1/1
# 50/50 [==============================] - 0s 419us/step - loss: 0.5286
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.5331
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5305
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5174
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.5197
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5267
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4621
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.5031
# Epoch 1/1
# 50/50 [==============================] - 0s 439us/step - loss: 0.5283
# Epoch 1/1
# 50/50 [==============================] - 0s 499us/step - loss: 0.5078
# Epoch 1/1
# 50/50 [==============================] - 0s 501us/step - loss: 0.4667
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4869
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5283
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.5155
# Epoch 1/1
# 50/50 [==============================] - 0s 640us/step - loss: 0.5103
# Epoch 1/1
# 50/50 [==============================] - 0s 700us/step - loss: 0.4874
# Epoch 1/1
# 50/50 [==============================] - 0s 860us/step - loss: 0.5001
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.4980
# Epoch 1/1
# 44/44 [==============================] - 0s 545us/step - loss: 0.5339
# Epoch 1/1
# 50/50 [==============================] - 0s 791us/step - loss: 0.5362
# Epoch 1/1
# 50/50 [==============================] - 0s 565us/step - loss: 0.4879
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5380
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5174
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5059
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5331
# Epoch 1/1
# 50/50 [==============================] - 0s 543us/step - loss: 0.4769
# Epoch 1/1
# 50/50 [==============================] - 0s 680us/step - loss: 0.4759
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4889
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4826
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5183
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4753
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4810
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5102
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5017
# Epoch 1/1
# 50/50 [==============================] - 0s 880us/step - loss: 0.5563
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5139
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.4581
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5093
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5092
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5078
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4673
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4868
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.4769
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4646
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5043
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.4849
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5330
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5172
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4839
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5131
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.4800
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.4862
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.5139
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.4678
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5012
# Epoch 1/1
# 50/50 [==============================] - 0s 580us/step - loss: 0.4701
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4701
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4889
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4666
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4696
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4809
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.5269
# Epoch 1/1
# 44/44 [==============================] - 0s 659us/step - loss: 0.5315
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4883
# Epoch 1/1
# 50/50 [==============================] - 0s 538us/step - loss: 0.4912
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4772
# Epoch 1/1
# 50/50 [==============================] - 0s 499us/step - loss: 0.4885
# Epoch 1/1
# 50/50 [==============================] - 0s 481us/step - loss: 0.4546
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4968
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4857
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4925
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4712
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4873
# Epoch 1/1
# 50/50 [==============================] - 0s 539us/step - loss: 0.5001
# Epoch 1/1
# 50/50 [==============================] - 0s 1ms/step - loss: 0.5021
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4578
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4398
# Epoch 1/1
# 50/50 [==============================] - 0s 431us/step - loss: 0.4657
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4655
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.5013
# Epoch 1/1
# 50/50 [==============================] - 0s 624us/step - loss: 0.4657
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4761
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4751
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4751
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.5085
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4791
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4340
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4522
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4981
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4721
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4842
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4828
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4883
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.5022
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.5218
# Epoch 1/1
# 50/50 [==============================] - 0s 311us/step - loss: 0.5123
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.5104
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4730
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4837
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.4779
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4709
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.5016
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4626
# Epoch 1/1
# 50/50 [==============================] - 0s 312us/step - loss: 0.4797
# Epoch 1/1
# 50/50 [==============================] - 0s 313us/step - loss: 0.5159
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4827
# Epoch 1/1
# 44/44 [==============================] - 0s 355us/step - loss: 0.4560
# Epoch 1/1
# 50/50 [==============================] - 0s 285us/step - loss: 0.4456
# Epoch 1/1
# 50/50 [==============================] - 0s 742us/step - loss: 0.4734
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4709
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4628
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5241
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.5063
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4627
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.5219
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5178
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4904
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4790
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4895
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4811
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4833
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4806
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4687
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4982
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4711
# Epoch 1/1
# 50/50 [==============================] - 0s 501us/step - loss: 0.4773
# Epoch 1/1
# 50/50 [==============================] - 0s 539us/step - loss: 0.4675
# Epoch 1/1
# 50/50 [==============================] - 0s 461us/step - loss: 0.4470
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4847
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4516
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4970
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4864
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4380
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4675
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4751
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4799
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4723
# Epoch 1/1
# 50/50 [==============================] - 0s 600us/step - loss: 0.4388
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4779
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4601
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4920
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4584
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4713
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4688
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5009
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4871
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4194
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4449
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4513
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4630
# Epoch 1/1
# 44/44 [==============================] - 0s 545us/step - loss: 0.4609
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4593
# Epoch 1/1
# 50/50 [==============================] - 0s 588us/step - loss: 0.4409
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4869
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4460
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5012
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4530
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4589
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4484
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4719
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5023
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4656
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4668
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4800
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4702
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4604
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4553
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4962
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.5451
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4984
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4488
# Epoch 1/1
# 50/50 [==============================] - 0s 459us/step - loss: 0.4761
# Epoch 1/1
# 50/50 [==============================] - 0s 441us/step - loss: 0.4627
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4484
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4838
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4284
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4850
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4656
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4747
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4437
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4446
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4474
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4757
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4636
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4584
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4830
# Epoch 1/1
# 50/50 [==============================] - 0s 461us/step - loss: 0.4535
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4456
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4526
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4659
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4955
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4632
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4285
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4783
# Epoch 1/1
# 44/44 [==============================] - 0s 545us/step - loss: 0.4753
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4338
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4530
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4319
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4639
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4510
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4590
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4605
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5012
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4298
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4836
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5033
# Epoch 1/1
# 50/50 [==============================] - 0s 540us/step - loss: 0.4772
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4690
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4614
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4414
# Epoch 1/1
# 50/50 [==============================] - 0s 440us/step - loss: 0.4630
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4498
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4527
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4435
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4588
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4779
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4134
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4473
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4761
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4446
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4328
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4603
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4385
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4570
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4675
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4599
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4747
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.5176
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4625
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4652
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4705
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4524
# Epoch 1/1
# 50/50 [==============================] - 0s 560us/step - loss: 0.4455
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4489
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4493
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4631
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4654
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4840
# Epoch 1/1
# 44/44 [==============================] - 0s 500us/step - loss: 0.4884
# Epoch 1/1
# 50/50 [==============================] - 0s 625us/step - loss: 0.4666
# Epoch 1/1
# 50/50 [==============================] - 0s 633us/step - loss: 0.4549
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4260
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4402
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4760
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4765
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4472
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4454
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4529
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4431
# Epoch 1/1
# 50/50 [==============================] - 0s 420us/step - loss: 0.4490
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4443
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4500
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4219
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4338
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4501
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4754
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4706
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4503
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4192
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4892
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4297
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4122
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4941
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4870
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4291
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4453
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4391
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4626
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4556
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4552
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4845
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4751
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4651
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4390
# Epoch 1/1
# 50/50 [==============================] - 0s 420us/step - loss: 0.4515
# Epoch 1/1
# 50/50 [==============================] - 0s 500us/step - loss: 0.4545
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4675
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4194
# Epoch 1/1
# 50/50 [==============================] - 0s 460us/step - loss: 0.4776
# Epoch 1/1
# 50/50 [==============================] - 0s 520us/step - loss: 0.4572
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4541
# Epoch 1/1
# 50/50 [==============================] - 0s 480us/step - loss: 0.4421
# Epoch 1/1
# 44/44 [==============================] - 0s 545us/step - loss: 0.4233

# %%
# Initialize an iterator over a testing dataset.
sess.run(iter.initializer, feed_dict={image_paths: test_paths})
    
# get batch
test_batch_X = sess.run(next_ele)

# show the test images
show_images(test_batch_X)

# create encoded images
encoded_imgs = autoencoder.predict(test_batch_X)

# create decoded images
decoded_imgs = autoencoder.predict(encoded_imgs)

# show the reconstructioned test images
show_images(decoded_imgs)
