# %% [markdown]
# # AnimeGM - Autoencoder - Keras
# GOAL: Generate new anime-style images
#
# Methodology:
# 1. Build a dataset of images suitable for out needs
# 2. Build a generative model.
# 3. Train the model
# 4. Generate a new image with random numbers
# 5. Transfer style to a photo
# 6. Examine results

# %% [markdown]
# ## 1. Build a dataset
# Pull in an existing dataset and modify it for my needs.
#
# Lets start with the danbooru 2017 anime image dataset. Now this dataset is huge. So we are only going to use 1 torrent of the SFW subset.

# %% [markdown]
# ### Imports

# %%
import pandas as pd
from scipy import misc
import numpy as np
import matplotlib.pyplot as plt
from skimage import color
import seaborn as sns; sns.set()
from skimage.transform import resize
from os import listdir
from os.path import join
from skimage import data
import tensorflow as tf
from tensorflow.python.framework.ops import reset_default_graph
# %matplotlib inline

# %% [markdown]
# ### Functions

# %%
# tf image preprocessing
# load, decoded and resize
def parse_image(image_path):
    image_string = tf.read_file(image_path)
    image_decoded = tf.image.decode_jpeg(image_string, channels=3)
    image_resized = tf.image.resize_images(image_decoded, [resize_dim, resize_dim])
    image_normalized = tf.divide(image_resized, 255)
    image_reshaped = tf.reshape(image_normalized, [-1])
    return image_reshaped

# %%
def show_image(image):
    image_reshape = image.reshape((resize_dim, resize_dim, 3))
    plt.imshow(image_reshape, cmap='gray')
    plt.xticks([])
    plt.yticks([])
    plt.show()

# %%
def show_images(images, figsize=(10, 10)):
   # get the number of images
    n_images = images.shape[0]
    
    if n_images == 1:
        show_image(images[0])
        return
    
    # get the square root of the number of images
    squareroot = int(np.ceil(np.sqrt(n_images)))
    
    fig, ax = plt.subplots(squareroot, squareroot, figsize=figsize,
                           subplot_kw=dict(xticks=[], yticks=[]))
    fig.subplots_adjust(hspace=0.05, wspace=0.05)

    for i, axi in enumerate(ax.flat):
        # exit if the index of subplots is greater than amount of images
        if i > n_images - 1:
            return
        image_reshape = images[i].reshape((resize_dim, resize_dim, 3))
        im = axi.imshow(image_reshape, cmap='gray')

# %% [markdown]
# ### Variables

# %%
dir_name = 'danbooru-small'

# %%
n_train = 2200
n_test = 10

resize_dim = 128
n_features = resize_dim * resize_dim * 3

# %%
# hyper parameters~~~~
batch_size = 100
n_batches = int(n_train / batch_size)
n_epochs = 1

# %% [markdown]
# ### Prepare data

# %%
# get filenames and join paths as np array
base_filenames = listdir(dir_name)
filename_paths = [join(dir_name, base_filename) for base_filename in base_filenames]
filename_paths = np.array(filename_paths)

# %%
# create paths for train and test
train_paths = filename_paths[:-n_test][:n_train]
test_paths = filename_paths[:n_test]

# %%
# reset the current graph and start over
reset_default_graph()

# %%
# create a dataset from the paths
image_paths = tf.placeholder(tf.string, shape=[None])
dataset = tf.data.Dataset.from_tensor_slices(image_paths)
dataset = dataset.map(parse_image)
dataset = dataset.shuffle(buffer_size=n_train)
dataset = dataset.batch(batch_size)
dataset = dataset.repeat()

# iterators
iter = dataset.make_initializable_iterator()
next_ele = iter.get_next()

# %%
# create a session to use the graph
sess = tf.Session()

# Initialize an iterator over a testing dataset.
sess.run(iter.initializer, feed_dict={image_paths: test_paths})
    
# get batch
test_batch_X = sess.run(next_ele)

# show the test images
show_images(test_batch_X)

# %% [markdown]
# ## 2. Build a generative model
# Lets build an autoencoder

# %%
import keras
from keras.layers import Dense, Input, Reshape
from keras.models import Model
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
# size of encoded representations
encoding_dims = 28

# %%
# input placeholder
inputs = Input(shape=(n_features,))

# encoded represation of the input
encoded = Dense(256, activation='relu', name='encoder_0')(inputs)
encoded = Dense(128, activation='relu', name='encoder_1')(encoded)
encoded = Dense(64, activation='relu', name='encoder_2')(encoded)
encoded = Dense(encoding_dims, activation='relu', name='encoder_3')(encoded)

# decoded lossy reconstruction of the input
decoded = Dense(64, activation='relu', name='decoder_0')(encoded)
decoded = Dense(128, activation='relu', name='decoder_1')(decoded)
decoded = Dense(256, activation='relu', name='decoder_2')(decoded)
decoded = Dense(n_features, activation='sigmoid', name='decoder_3')(decoded)

# %%
# this model maps inputs to its reconstructions
autoencoder = Model(inputs, decoded)

# %%
# this model maps inputs to encoded represations
encoder = Model(inputs, encoded)

# %%
# create a placeholder for an ancoded input
encoded_input = Input(shape=(encoding_dims,))

# get the last layer of the autoencoder model
decoder_layer = autoencoder.layers[-4]

# create decoder model
decoder = Model(encoded_input, decoder_layer(encoded_input))

# %% [markdown]
# ### Compile the model with cost and optimizer

# %%
autoencoder.compile(loss='binary_crossentropy', 
              optimizer='adadelta')

# %% [markdown]
# ## 3. Train the model

# %%
# create a session to use the graph
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
# Initialize an iterator over a training dataset.
sess.run(iter.initializer, feed_dict={image_paths: train_paths})
    
for epoch_i in range(n_epochs):
    for batch_i in range(n_batches):
        # get batch
        batch_X = sess.run(next_ele)

        # train
        autoencoder.fit(batch_X, batch_X, epochs=1, batch_size=batch_size)
# Out:
# Epoch 1/1
# 10/10 [==============================] - 3s 304ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 139ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 146ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 130ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 128ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 128ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 1s 141ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 2s 161ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 2s 163ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 150ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 161ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 164ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 178ms/step - loss: 0.6932
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 209ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 166ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 168ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 205ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 184ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 176ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 175ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 171ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 186ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 170ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 195ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 186ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 191ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 181ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 151ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 178ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 181ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 176ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 190ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 178ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 185ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 176ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 213ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 222ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 190ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 210ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 190ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 195ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 164ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6931
# Epoch 1/1
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 173ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 158ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 161ms/step - loss: 0.6929
# Epoch 1/1
# 10/10 [==============================] - 2s 162ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6929
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6930
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6929
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.6928
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6927
# Epoch 1/1
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6927
# Epoch 1/1
# 10/10 [==============================] - 2s 191ms/step - loss: 0.6926
# Epoch 1/1
# 10/10 [==============================] - 2s 195ms/step - loss: 0.6926
# Epoch 1/1
# 10/10 [==============================] - 2s 180ms/step - loss: 0.6925
# Epoch 1/1
# 10/10 [==============================] - 2s 188ms/step - loss: 0.6924
# Epoch 1/1
# 10/10 [==============================] - 2s 175ms/step - loss: 0.6923
# Epoch 1/1
# 10/10 [==============================] - 2s 194ms/step - loss: 0.6922
# Epoch 1/1
# 10/10 [==============================] - 2s 192ms/step - loss: 0.6922
# Epoch 1/1
# 10/10 [==============================] - 2s 190ms/step - loss: 0.6919
# Epoch 1/1
# 10/10 [==============================] - 2s 182ms/step - loss: 0.6917
# Epoch 1/1
# 10/10 [==============================] - 2s 198ms/step - loss: 0.6923
# Epoch 1/1
# 10/10 [==============================] - 2s 194ms/step - loss: 0.6919
# Epoch 1/1
# 10/10 [==============================] - 2s 217ms/step - loss: 0.6915
# Epoch 1/1
# 10/10 [==============================] - 2s 197ms/step - loss: 0.6917
# Epoch 1/1
# 10/10 [==============================] - 2s 193ms/step - loss: 0.6914
# Epoch 1/1
# 10/10 [==============================] - 2s 186ms/step - loss: 0.6921
# Epoch 1/1
# 10/10 [==============================] - 2s 167ms/step - loss: 0.6914
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6921
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6906
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6906
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6894
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.6902
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6904
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6884
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.6875
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6879
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6868
# Epoch 1/1
# 10/10 [==============================] - 2s 164ms/step - loss: 0.6855
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6835
# Epoch 1/1
# 10/10 [==============================] - 2s 160ms/step - loss: 0.6837
# Epoch 1/1
# 10/10 [==============================] - 2s 157ms/step - loss: 0.6841
# Epoch 1/1
# 10/10 [==============================] - 2s 171ms/step - loss: 0.6825
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.6785
# Epoch 1/1
# 10/10 [==============================] - 2s 173ms/step - loss: 0.6789
# Epoch 1/1
# 10/10 [==============================] - 2s 173ms/step - loss: 0.6772
# Epoch 1/1
# 10/10 [==============================] - 2s 221ms/step - loss: 0.6598
# Epoch 1/1
# 10/10 [==============================] - 2s 190ms/step - loss: 0.6850
# Epoch 1/1
# 10/10 [==============================] - 2s 223ms/step - loss: 0.6500
# Epoch 1/1
# 10/10 [==============================] - 2s 197ms/step - loss: 0.6726
# Epoch 1/1
# 10/10 [==============================] - 2s 191ms/step - loss: 0.6581
# Epoch 1/1
# 10/10 [==============================] - 2s 189ms/step - loss: 0.6479
# Epoch 1/1
# 10/10 [==============================] - 2s 210ms/step - loss: 0.6685
# Epoch 1/1
# 10/10 [==============================] - 2s 185ms/step - loss: 0.6327
# Epoch 1/1
# 10/10 [==============================] - 2s 186ms/step - loss: 0.6236
# Epoch 1/1
# 10/10 [==============================] - 2s 195ms/step - loss: 0.6404
# Epoch 1/1
# 10/10 [==============================] - 2s 204ms/step - loss: 0.5667
# Epoch 1/1
# 10/10 [==============================] - 2s 177ms/step - loss: 0.5330
# Epoch 1/1
# 10/10 [==============================] - 2s 197ms/step - loss: 0.6289
# Epoch 1/1
# 10/10 [==============================] - 2s 181ms/step - loss: 0.5816
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.5638
# Epoch 1/1
# 10/10 [==============================] - 2s 177ms/step - loss: 0.6719
# Epoch 1/1
# 10/10 [==============================] - 2s 189ms/step - loss: 0.6016
# Epoch 1/1
# 10/10 [==============================] - 2s 168ms/step - loss: 0.5132
# Epoch 1/1
# 10/10 [==============================] - 2s 172ms/step - loss: 0.5582
# Epoch 1/1
# 10/10 [==============================] - 2s 165ms/step - loss: 0.5331
# Epoch 1/1
# 10/10 [==============================] - 2s 165ms/step - loss: 0.5550
# Epoch 1/1
# 10/10 [==============================] - 2s 159ms/step - loss: 0.5349
# Epoch 1/1
# 10/10 [==============================] - 2s 192ms/step - loss: 0.5005
# Epoch 1/1
# 10/10 [==============================] - 2s 186ms/step - loss: 0.5847
# Epoch 1/1
# 10/10 [==============================] - 2s 179ms/step - loss: 0.6100
# Epoch 1/1
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5686
# Epoch 1/1
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5737
# Epoch 1/1
# 10/10 [==============================] - 2s 178ms/step - loss: 0.5094
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.6074
# Epoch 1/1
# 10/10 [==============================] - 2s 150ms/step - loss: 0.5358
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.4867
# Epoch 1/1
# 10/10 [==============================] - 2s 193ms/step - loss: 0.5643
# Epoch 1/1
# 10/10 [==============================] - 2s 179ms/step - loss: 0.4658
# Epoch 1/1
# 10/10 [==============================] - 2s 167ms/step - loss: 0.4678
# Epoch 1/1
# 10/10 [==============================] - 2s 170ms/step - loss: 0.4860
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5443
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.5419
# Epoch 1/1
# 10/10 [==============================] - 2s 178ms/step - loss: 0.5198
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.4987
# Epoch 1/1
# 10/10 [==============================] - 2s 156ms/step - loss: 0.5707
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5101
# Epoch 1/1
# 10/10 [==============================] - 2s 153ms/step - loss: 0.5403
# Epoch 1/1
# 10/10 [==============================] - 2s 151ms/step - loss: 0.5869
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5134
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5175
# Epoch 1/1
# 10/10 [==============================] - 2s 153ms/step - loss: 0.5187
# Epoch 1/1
# 10/10 [==============================] - 2s 151ms/step - loss: 0.5625
# Epoch 1/1
# 10/10 [==============================] - 2s 153ms/step - loss: 0.4772
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.5233
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.5473
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.5018
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5325
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.5493
# Epoch 1/1
# 10/10 [==============================] - 2s 163ms/step - loss: 0.4175
# Epoch 1/1
# 10/10 [==============================] - 2s 176ms/step - loss: 0.5263
# Epoch 1/1
# 10/10 [==============================] - 2s 170ms/step - loss: 0.5157
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.5016
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.5454
# Epoch 1/1
# 10/10 [==============================] - 2s 153ms/step - loss: 0.4940
# Epoch 1/1
# 10/10 [==============================] - 2s 155ms/step - loss: 0.6026
# Epoch 1/1
# 10/10 [==============================] - 2s 154ms/step - loss: 0.4655
# Epoch 1/1
# 10/10 [==============================] - 2s 152ms/step - loss: 0.4485
# Epoch 1/1
# 10/10 [==============================] - 2s 151ms/step - loss: 0.5056
# Epoch 1/1
# 10/10 [==============================] - 2s 153ms/step - loss: 0.6415
# Epoch 1/1
# 10/10 [==============================] - 2s 167ms/step - loss: 0.5421
# Epoch 1/1
# 10/10 [==============================] - 2s 201ms/step - loss: 0.5419
# Epoch 1/1
# 10/10 [==============================] - 1s 148ms/step - loss: 0.4847
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5041
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5839
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5880
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5345
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.4976
# Epoch 1/1
# 10/10 [==============================] - 1s 128ms/step - loss: 0.5391
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5474
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5860
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5572
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.4712
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5544
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.4676
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5632
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4523
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.4632
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5450
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4572
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5231
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4982
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4630
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4892
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5943
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5509
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5123
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5717
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5129
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5531
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5812
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4984
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5381
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.4728
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5330
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.4783
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.5195
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5068
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5066
# Epoch 1/1
# 10/10 [==============================] - 1s 122ms/step - loss: 0.6333
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.4887
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5660
# Epoch 1/1
# 10/10 [==============================] - 1s 123ms/step - loss: 0.5002
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5502
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5882
# Epoch 1/1
# 10/10 [==============================] - 1s 125ms/step - loss: 0.5322
# Epoch 1/1
# 10/10 [==============================] - 1s 126ms/step - loss: 0.4906
# Epoch 1/1
# 10/10 [==============================] - 1s 127ms/step - loss: 0.5608
# Epoch 1/1
# 10/10 [==============================] - 1s 124ms/step - loss: 0.5185
# Epoch 1/1
# 4/4 [==============================] - 1s 303ms/step - loss: 0.5282

# %%
# Initialize an iterator over a testing dataset.
sess.run(iter.initializer, feed_dict={image_paths: test_paths})
    
# get batch
test_batch_X = sess.run(next_ele)

# show the test images
show_images(test_batch_X)

# create encoded images
encoded_imgs = autoencoder.predict(test_batch_X)

# create decoded images
decoded_imgs = autoencoder.predict(encoded_imgs)

# show the reconstructioned test images
show_images(decoded_imgs)
